# %%
import nibabel as nib
import matplotlib.pyplot as plt

# %%
ct_data = nib.load('Data\Zx00AD16F8B97A53DE6E7CFE260BDF122F0E655659A3DF1628.nii.gz')
ct_data = ct_data.get_fdata()

# %%
slice = ct_data[:,256,:].T
slice = slice[::-1,:]

# %%
# extennd z to 5 times using nearest neighbour interpolation
import cv2
slice = cv2.resize(slice, (512,512), interpolation = cv2.INTER_NEAREST)
plt.imshow(slice, cmap='gray')
